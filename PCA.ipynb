# %% [markdown]
# # PCA on Diabetes Dataset

# %%
from sklearn.datasets import load_diabetes

data = load_diabetes(as_frame = True).frame
data.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
x = data.drop(columns = 'target')

# %%
x.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
from sklearn.decomposition import PCA
pca = PCA(10)
pca.fit(x)
# Out:
# PCA(n_components=10)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %%
pca = PCA(8)

# %%
import pandas as pd
coms = pd.DataFrame(pca.fit_transform(x),columns = [f'PC-{i}' for i in range(1,9)])
coms
# Out:
#          PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0    0.027930 -0.092601  0.028026 -0.003939 -0.012209 -0.048098 -0.008554
# 1   -0.134687  0.065263  0.001328 -0.022356 -0.006815 -0.048184  0.010674
# 2    0.012944 -0.077764  0.035162 -0.037647 -0.055360 -0.052929 -0.021997
# 3    0.002344  0.018183 -0.095750  0.065317  0.012156  0.021180  0.022931
# 4   -0.035979  0.038621 -0.002723 -0.006540 -0.006345 -0.038745  0.020764
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.058958 -0.049276  0.044173 -0.031215  0.009717 -0.022802  0.018760
# 438  0.060157  0.036212 -0.083248 -0.053913 -0.004470  0.046302 -0.055818
# 439 -0.009761 -0.057339  0.023601 -0.064373 -0.006734 -0.002157 -0.030223
# 440  0.032957  0.009995 -0.041321  0.076903  0.005690 -0.026489  0.025956
# 441 -0.090561  0.189108 -0.002299 -0.010494  0.028537  0.078342  0.011663
#
#          PC-8
# 0    0.036027
# 1   -0.008963
# 2    0.040107
# 3   -0.017498
# ...

# %% [markdown]
#  - Credit card Fraud

# %%
df = pd.read_csv(r"C:\Users\Raksha Chavan\Downloads\creditcard.csv\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.drop('Class' , axis = 1 , inplace = True)

# %%
df.drop('Time' , axis = 1 , inplace = True)

# %%
df.head(2)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
#
#         V24       V25       V26       V27       V28  Amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
#
# [2 rows x 29 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(10)
pca.fit(df)
# Out:
# PCA(n_components=10)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %%
pca = PCA(7)

# %%
import pandas as pd
coms = pd.DataFrame(pca.fit_transform(df),columns = [f'PC-{i}' for i in range(1,8)])
coms
# Out:
#               PC-1       PC-2       PC-3      PC-4      PC-5      PC-6  \
# 0        61.271382   1.320973  -1.298607 -2.365480  1.129530 -0.231564
# 1       -85.661826  -1.043397   0.119571 -0.260438  0.455816  0.014537
# 2       290.316696   0.813151  -1.343674 -1.769875  0.095164 -1.343164
# 3        35.151659   0.927515  -1.108463 -1.394005 -1.004650 -1.152756
# 4       -18.360281   1.316058  -0.158405 -1.745913  0.156209 -0.014990
# ...            ...        ...        ...       ...       ...       ...
# 284802  -87.586281  13.122413  12.170027  4.230395 -2.653235  5.924706
# 284803  -63.560584   0.877488  -1.483849 -1.160514 -0.662399 -1.452553
# 284804  -20.470739  -1.970275   1.356825  3.304846  0.003002 -3.623288
# 284805  -78.350638   0.409424  -0.025214 -0.845142  0.525182 -0.056940
# 284806  128.652188   0.359021  -0.324676 -0.678931 -0.589302  0.149207
#
#             PC-7
# 0       0.109116
# 1       0.017720
# 2       0.485228
# 3       0.234958
# 4      -0.437091
# ...

# %% [markdown]
# # Wine Dataset

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
from sklearn.datasets import load_wine
data = load_wine(as_frame = True).frame

# %%
data.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(data)
x_scaled
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  1.84791957,
#          1.01300893, -1.21394365],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  1.1134493 ,
#          0.96524152, -1.21394365],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.78858745,
#          1.39514818, -1.21394365],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.48544548,
#          0.28057537,  1.37386437],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.40069891,
#          0.29649784,  1.37386437],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.42894777,
#         -0.59516041,  1.37386437]])

# %%
data.drop('target', axis = 1, inplace = True)

# %%
data.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
data.shape
# Out:
# (178, 13)

# %%
from sklearn.decomposition import PCA
pca = PCA(4)
pca.fit(data)
# Out:
# PCA(n_components=4)

# %%
var = pca.explained_variance_ratio_
var
pca.components_[0]
# Out:
# array([ 1.65926472e-03, -6.81015556e-04,  1.94905742e-04, -4.67130058e-03,
#         1.78680075e-02,  9.89829680e-04,  1.56728830e-03, -1.23086662e-04,
#         6.00607792e-04,  2.32714319e-03,  1.71380037e-04,  7.04931645e-04,
#         9.99822937e-01])

# %%
var1 = np.cumsum(np.round(var,decimals = 4)*100)
var1
# Out:
# array([ 99.81,  99.98,  99.99, 100.  ])

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
